# %% [markdown]
# <a href="https://colab.research.google.com/github/chernoskutov1989dv/Self-Education/blob/main/sentiment_analysis_se_24_chernoskutov_dmitry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import re

from tensorflow.keras.layers import Dense, LSTM, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
open ("/content/train_data_true.txt")
open ("/content/train_data_false.txt")
# Out:
# <_io.TextIOWrapper name='/content/train_data_false.txt' mode='r' encoding='UTF-8'>

# %%
with open ("train_data_true.txt", "r", encoding = "utf-8") as f:
    texts_true = f.readlines()
    texts_true [0] = texts_true[0].replace ("\ufeff", " ")

# %%
with open ("train_data_false.txt", "r", encoding = "utf-8") as f:
    texts_false = f.readlines()
    texts_false [0] = texts_false[0].replace ("\ufeff", " ")

# %%
texts = texts_true + texts_false

count_true = len(texts_true)

count_false = len(texts_false)

total_lines = count_true + count_false

# %%
print (count_true, count_false, total_lines)
# Out:
# 84 88 172

# %%
maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])
# Out:
# [('думайте', 1), ('позитивно', 4), ('и', 50), ('верьте', 3), ('в', 38), ('свою', 4), ('способность', 1), ('достигать', 1), ('отличных', 1), ('результатов', 1)]
#  Думайте позитивно и верьте в свою способность достигать отличных результатов.

# %%
max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)
print( list(tokenizer.word_index.items()) )
# Out:
# [[197  54   2 ... 199 200 201]
#  [  0   4 202 ... 205   3  67]
#  [206   3  67 ...   4 208 209]
#  ...
#  [  0  20  62 ...  53 850 851]
#  [  0   0  43 ...  33   1 853]
#  [  0   0   0 ...  70  65 194]]
# [('не', 1), ('и', 2), ('в', 3), ('вы', 4), ('на', 5), ('я', 6), ('а', 7), ('только', 8), ('что', 9), ('все', 10), ('это', 11), ('если', 12), ('жизнь', 13), ('просто', 14), ('с', 15), ('чем', 16), ('никогда', 17), ('чтобы', 18), ('к', 19), ('у', 20), ('больше', 21), ('себя', 22), ('то', 23), ('всегда', 24), ('вас', 25), ('меня', 26), ('за', 27), ('вам', 28), ('когда', 29), ('от', 30), ('мне', 31), ('быть', 32), ('жизни', 33), ('есть', 34), ('но', 35), ('сделать', 36), ('без', 37), ('позитивным', 38), ('никому', 39), ('как', 40), ('ты', 41), ('тем', 42), ('для', 43), ('день', 44), ('позитивное', 45), ('своих', 46), ('мы', 47), ('много', 48), ('тебя', 49), ('никто', 50), ('такой', 51), ('деньги', 52), ('денег', 53), ('позитивно', 54), ('свою', 55), ('которые', 56), ('значит', 57), ('так', 58), ('них', 59), ('мечты', 60), ('нужно', 61), ('того', 62), ('ничего', 63), ('лучше', 64), ('надо', 65), ('верьте', 66), ('понедельник', 67), ('живи', 68), ('позволяйте', 69), ('хорошее', 70), ('можете', 71), ('ваши', 72), ('других', 73), ('делай', 74), ('тебе', 75), ('можешь', 76), ('успеха', 77), ('ваша', 78), ('стоит', 79), ('себе', 80), ('своей', 81), ('их', 82), ('позитив', 83), ('свои', 84), ('о', 85), ('энергию', 86), ('более', 87), ('делать', 88), ('по', 89), ('или', 90), ('нет', 91), ('кто', 92), ('во', 93), ('успеху', 94), ('пусть', 95), ('опасно', 96), ('равно', 97), ('ни', 98), ('же', 99), ('сама', 100), ('болезней', 101), ('подняться', 102), ('жизнью', 103), ('времена', 104), ('величайшим', 105), ('вашей', 106), ('продолжайте', 107), ('двигаться', 108), ('конце', 109), ('сильных', 110), ('людей', 111), ('свет', 112), ('может', 113), ('до', 114), ('настроены', 115), ('иметь', 116), ('хорошую', 117), ('строите', 118), ('эту', 119), ('позитивного', 120), ('отношения', 121), ('чудеса', 122), ('способности', 123), ('достичь', 124), ('оставайся', 125), ('доверяй', 126), ('твой', 127), ('вещи', 128), ('приносят', 129), ('радость', 130), ('верь', 131), ('опыт', 132), ('отношение', 133), ('собираетесь', 134), ('выбор', 135), ('позитивный', 136), ('всю', 137), ('свое', 138), ('время', 139), ('обиды', 140), ('думаете', 141), ('потому', 142), ('каждый', 143), ('позитивные', 144), ('позитивной', 145), ('можем', 146), ('позитивную', 147), ('станет', 148), ('контролируете', 149), ('будьте', 150), ('возможности', 151), ('таланты', 152), ('были', 153), ('из', 154), ('два', 155), ('должен', 156), ('превращай', 157), ('которую', 158), ('стать', 159), ('делает', 160), ('человека', 161), ('нужны', 162), ('либо', 163), ('всем', 164), ('настроем', 165), ('почему', 166), ('позитивность', 167), ('самое', 168), ('главное', 169), ('один', 170), ('сейчас', 171), ('вокруг', 172), ('бы', 173), ('кому', 174), ('нужен', 175), ('внешностью', 176), ('могу', 177), ('точно', 178), ('поэтому', 179), ('даже', 180), ('такая', 181), ('любит', 182), ('плохая', 183), ('мой', 184), ('этого', 185), ('тут', 186), ('этих', 187), ('тогда', 188), ('болею', 189), ('бывает', 190), ('хоть', 191), ('бывают', 192), ('заработать', 193), ('платить', 194), ('богатство', 195), ('зависти', 196), ('думайте', 197), ('способность', 198), ('достигать', 199), ('отличных', 200), ('результатов', 201), ('лучший', 202), ('ответ', 203), ('проблемы', 204), ('возникли', 205), ('смогли', 206), ('постели', 207), ('супер', 208), ('герой', 209), ('твои', 210), ('утренние', 211), ('мысли', 212), ('задают', 213), ('тон', 214), ('всей', 215), ('твоей', 216), ('неделе', 217), ('увидеть', 218), ('становишься', 219), ('сильнее', 220), ('живешь', 221), ('счастливой', 222), ('полноценной', 223), ('утренним', 224), ('проблемам', 225), ('помешать', 226), ('успешным', 227), ('тяжелые', 228), ('часто', 229), ('приводят', 230), ('моментам', 231), ('трудности', 232), ('концов', 233), ('создают', 234), ('независимо', 235), ('через', 236), ('проходите', 237), ('туннеля', 238), ('показаться', 239), ('добраться', 240), ('него', 241), ('сложно', 242), ('сможете', 243), ('говорите', 244), ('хочу', 245), ('реальность', 246) ...

# %%
print (list (tokenizer.word_index.items()))
X = data_pad
Y = np.array ([[1, 0]] * count_true +[[0, 1]] *count_false)
print (X.shape, Y.shape)
indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indeces]
Y = Y[indeces]
# Out:
# [('не', 1), ('и', 2), ('в', 3), ('вы', 4), ('на', 5), ('я', 6), ('а', 7), ('только', 8), ('что', 9), ('все', 10), ('это', 11), ('если', 12), ('жизнь', 13), ('просто', 14), ('с', 15), ('чем', 16), ('никогда', 17), ('чтобы', 18), ('к', 19), ('у', 20), ('больше', 21), ('себя', 22), ('то', 23), ('всегда', 24), ('вас', 25), ('меня', 26), ('за', 27), ('вам', 28), ('когда', 29), ('от', 30), ('мне', 31), ('быть', 32), ('жизни', 33), ('есть', 34), ('но', 35), ('сделать', 36), ('без', 37), ('позитивным', 38), ('никому', 39), ('как', 40), ('ты', 41), ('тем', 42), ('для', 43), ('день', 44), ('позитивное', 45), ('своих', 46), ('мы', 47), ('много', 48), ('тебя', 49), ('никто', 50), ('такой', 51), ('деньги', 52), ('денег', 53), ('позитивно', 54), ('свою', 55), ('которые', 56), ('значит', 57), ('так', 58), ('них', 59), ('мечты', 60), ('нужно', 61), ('того', 62), ('ничего', 63), ('лучше', 64), ('надо', 65), ('верьте', 66), ('понедельник', 67), ('живи', 68), ('позволяйте', 69), ('хорошее', 70), ('можете', 71), ('ваши', 72), ('других', 73), ('делай', 74), ('тебе', 75), ('можешь', 76), ('успеха', 77), ('ваша', 78), ('стоит', 79), ('себе', 80), ('своей', 81), ('их', 82), ('позитив', 83), ('свои', 84), ('о', 85), ('энергию', 86), ('более', 87), ('делать', 88), ('по', 89), ('или', 90), ('нет', 91), ('кто', 92), ('во', 93), ('успеху', 94), ('пусть', 95), ('опасно', 96), ('равно', 97), ('ни', 98), ('же', 99), ('сама', 100), ('болезней', 101), ('подняться', 102), ('жизнью', 103), ('времена', 104), ('величайшим', 105), ('вашей', 106), ('продолжайте', 107), ('двигаться', 108), ('конце', 109), ('сильных', 110), ('людей', 111), ('свет', 112), ('может', 113), ('до', 114), ('настроены', 115), ('иметь', 116), ('хорошую', 117), ('строите', 118), ('эту', 119), ('позитивного', 120), ('отношения', 121), ('чудеса', 122), ('способности', 123), ('достичь', 124), ('оставайся', 125), ('доверяй', 126), ('твой', 127), ('вещи', 128), ('приносят', 129), ('радость', 130), ('верь', 131), ('опыт', 132), ('отношение', 133), ('собираетесь', 134), ('выбор', 135), ('позитивный', 136), ('всю', 137), ('свое', 138), ('время', 139), ('обиды', 140), ('думаете', 141), ('потому', 142), ('каждый', 143), ('позитивные', 144), ('позитивной', 145), ('можем', 146), ('позитивную', 147), ('станет', 148), ('контролируете', 149), ('будьте', 150), ('возможности', 151), ('таланты', 152), ('были', 153), ('из', 154), ('два', 155), ('должен', 156), ('превращай', 157), ('которую', 158), ('стать', 159), ('делает', 160), ('человека', 161), ('нужны', 162), ('либо', 163), ('всем', 164), ('настроем', 165), ('почему', 166), ('позитивность', 167), ('самое', 168), ('главное', 169), ('один', 170), ('сейчас', 171), ('вокруг', 172), ('бы', 173), ('кому', 174), ('нужен', 175), ('внешностью', 176), ('могу', 177), ('точно', 178), ('поэтому', 179), ('даже', 180), ('такая', 181), ('любит', 182), ('плохая', 183), ('мой', 184), ('этого', 185), ('тут', 186), ('этих', 187), ('тогда', 188), ('болею', 189), ('бывает', 190), ('хоть', 191), ('бывают', 192), ('заработать', 193), ('платить', 194), ('богатство', 195), ('зависти', 196), ('думайте', 197), ('способность', 198), ('достигать', 199), ('отличных', 200), ('результатов', 201), ('лучший', 202), ('ответ', 203), ('проблемы', 204), ('возникли', 205), ('смогли', 206), ('постели', 207), ('супер', 208), ('герой', 209), ('твои', 210), ('утренние', 211), ('мысли', 212), ('задают', 213), ('тон', 214), ('всей', 215), ('твоей', 216), ('неделе', 217), ('увидеть', 218), ('становишься', 219), ('сильнее', 220), ('живешь', 221), ('счастливой', 222), ('полноценной', 223), ('утренним', 224), ('проблемам', 225), ('помешать', 226), ('успешным', 227), ('тяжелые', 228), ('часто', 229), ('приводят', 230), ('моментам', 231), ('трудности', 232), ('концов', 233), ('создают', 234), ('независимо', 235), ('через', 236), ('проходите', 237), ('туннеля', 238), ('показаться', 239), ('добраться', 240), ('него', 241), ('сложно', 242), ('сможете', 243), ('говорите', 244), ('хочу', 245), ('реальность', 246) ...
# (172, 10) (172, 2)

# %%
model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense (2, activation = "softmax"))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 10, 128)           128000
#
#  lstm_4 (LSTM)               (None, 10, 128)           131584
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 309,122
# Trainable params: 309,122
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer = Adam (0.0001))

# %%
history = model.fit(X, Y, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 3s 20ms/step - loss: 0.6915 - accuracy: 0.5814
# Epoch 2/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6877 - accuracy: 0.6337
# Epoch 3/50
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6837 - accuracy: 0.7616
# Epoch 4/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6791 - accuracy: 0.7849
# Epoch 5/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6736 - accuracy: 0.8140
# Epoch 6/50
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6663 - accuracy: 0.8256
# Epoch 7/50
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6561 - accuracy: 0.8430
# Epoch 8/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6437 - accuracy: 0.8547
# Epoch 9/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6258 - accuracy: 0.8547
# Epoch 10/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6037 - accuracy: 0.8605
# Epoch 11/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5784 - accuracy: 0.8605
# Epoch 12/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5468 - accuracy: 0.8663
# Epoch 13/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5185 - accuracy: 0.8663
# Epoch 14/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4899 - accuracy: 0.8663
# Epoch 15/50
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4632 - accuracy: 0.8663
# Epoch 16/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4372 - accuracy: 0.8605
# Epoch 17/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4106 - accuracy: 0.8605
# Epoch 18/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3825 - accuracy: 0.8779
# Epoch 19/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3548 - accuracy: 0.8895
# Epoch 20/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3275 - accuracy: 0.9012
# Epoch 21/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3010 - accuracy: 0.9128
# Epoch 22/50
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2754 - accuracy: 0.9128
# Epoch 23/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.2492 - accuracy: 0.9128
# Epoch 24/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2248 - accuracy: 0.9302
# Epoch 25/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2031 - accuracy: 0.9302
# Epoch 26/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1829 - accuracy: 0.9419
# Epoch 27/50
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1639 - accuracy: 0.9477
# Epoch 28/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1461 - accuracy: 0.9477
# Epoch 29/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1305 - accuracy: 0.9651
# Epoch 30/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1158 - accuracy: 0.9709
# Epoch 31/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.1033 - accuracy: 0.9767
# Epoch 32/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0903 - accuracy: 0.9767
# Epoch 33/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0811 - accuracy: 0.9767
# Epoch 34/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0715 - accuracy: 0.9767
# Epoch 35/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0645 - accuracy: 0.9826
# Epoch 36/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0589 - accuracy: 0.9826
# Epoch 37/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0529 - accuracy: 0.9826
# Epoch 38/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0484 - accuracy: 0.9826
# Epoch 39/50
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0444 - accuracy: 0.9826
# Epoch 40/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0418 - accuracy: 0.9826
# Epoch 41/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0378 - accuracy: 0.9884
# Epoch 42/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0366 - accuracy: 0.9884
# Epoch 43/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0364 - accuracy: 0.9884
# Epoch 44/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0301 - accuracy: 0.9884
# Epoch 45/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0291 - accuracy: 0.9942
# Epoch 46/50
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0278 - accuracy: 0.9942
# Epoch 47/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0249 - accuracy: 0.9942
# Epoch 48/50
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0231 - accuracy: 0.9942
# Epoch 49/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0214 - accuracy: 0.9942
# Epoch 50/50
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0213 - accuracy: 0.9942

# %%
reverse_word_map = dict (map(reversed, tokenizer.word_index.items()))

# %%
def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return (words)

# %%
t = "Не доверяй никому".lower()
#t = "Я люблю позитивное настроение".lower()

# %%
data = tokenizer.texts_to_sequences([t])

# %%
data_pad = pad_sequences(data, maxlen=max_text_len)
print (sequence_to_text(data[0]))
res = model.predict(data_pad)
# Out:
# ['не', 'доверяй', 'никому']
# 1/1 [==============================] - 1s 628ms/step

# %%
print(res, np.argmax(res), sep='\n')
# Out:
# [[0.13924108 0.86075896]]
# 1
